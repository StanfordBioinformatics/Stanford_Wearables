# %%
##Apple HealthKit File Paths

import xml.etree.ElementTree

AHK_export = '/Users/dsalins/Documents/SVNRepositories/Stanford_Wearables/data/DNS_export.xml'
AHK_cda_export = '/Users/dsalins/Documents/SVNRepositories/Stanford_Wearables/data/DNS_export_cda.xml'

all_xml = xml.etree.ElementTree.parse(AHK_export).getroot()

AHK_dict = dict()

for rec in all_xml:
    print(rec.find('source'))
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ...
